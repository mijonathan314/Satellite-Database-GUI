# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
commercial = pd.read_csv('Commercial.csv')
commercial.head()
# Out:
#       Company HQ Location                  Constellation Sensor Moda Update  \
# 0  LatConnect   Australia                   LatConnect60          EO    NaN
# 1   SATLANTIS    US/Spain                      SATLANTIS          EO    NaN
# 2      Zhuhai       China            Zhuhai-1 (OIS, OVS)          EO    NaN
# 3       Canon       Japan                         CE-SAT          EO    NaN
# 4       Theia          US  THEIA Satellite Network (TSN)          EO    NaN
#
#            Pan VNIR 400-1K nm Unnamed: 7 Unnamed: 8 LWIR 8K-12K nm  ...  \
# 0  0.5m<=x<=1m       1m<x<=5m        NaN        NaN            NaN  ...
# 1  0.5m<=x<=1m    0.5m<=x<=1m        NaN        NaN            NaN  ...
# 2  0.5m<=x<=1m            NaN        NaN        NaN      5m<x<=30m  ...
# 3          NaN    0.5m<=x<=1m        NaN        NaN            NaN  ...
# 4          NaN    0.5m<=x<=1m        NaN        NaN            NaN  ...
#
#   Band Width (nm) MWIR  Band Width (nm) LWIR Spectral Range (nm) VNIR.1  \
# 0                  NaN                   NaN                        NaN
# 1                  NaN                   NaN                        NaN
# 2                  NaN                   NaN                        NaN
# 3                  NaN                   NaN                        NaN
# 4                  NaN                   NaN                        NaN
#
#   Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 36
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 37 columns]

# %%
data = (commercial["Sensor Moda"] == "EO") & (commercial["Company"] == "LatConnect")
commercial[data]
# Out:
#       Company HQ Location Constellation Sensor Moda Update          Pan  \
# 0  LatConnect   Australia  LatConnect60          EO    NaN  0.5m<=x<=1m
#
#   VNIR 400-1K nm Unnamed: 7 Unnamed: 8 LWIR 8K-12K nm  ...  \
# 0       1m<x<=5m        NaN        NaN            NaN  ...
#
#   Band Width (nm) MWIR  Band Width (nm) LWIR Spectral Range (nm) VNIR.1  \
# 0                  NaN                   NaN                        NaN
#
#   Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 36
# 0         NaN
#
# [1 rows x 37 columns]

# %%
#Create list of Companies
c_array = np.unique(commercial["Company"].to_numpy()) 
print (c_array)

#Create unique list of Sensor Moda without &

def myFunc(string):
    if "&" in string:
        return False
    else:
        return True
s_array = np.unique(commercial["Sensor Moda"].to_numpy())
s_array_f = list(filter(myFunc, s_array))
s_array_f
# Out:
# ['21at; SSTL' 'ADA Space' 'AISTech Space' 'Acme AtronOmatic'
#  'Aerospacelab' 'Airbus' 'Airbus US' 'Airbus; Azercosmos' 'Aireon'
#  'Alba Orbital' 'Albedo' 'Alpha Insights (Urthecast)' 'Astro Digital'
#  'Astroscale' 'Aurora Insight' 'Austrian Space Forum (OeWF)' 'AxelSpace'
#  'BlackSky Technology Inc' 'BlackSky Technology Inc.' 'Bluefield' 'CAS'
#  'CETC' 'CNSA' 'Canadian Space Agency' 'Canon' 'Capella Space'
#  'Chang Guang' 'ConstellR' 'DMCii; SSTL' 'Deimos Imaging;Urthecast'
#  'Digantara' 'DragonFly; Space JLTZ' 'EOS' 'Earth - I'
#  'Earth Observant (EOI)' 'EarthDaily Analytics' 'GHGSat Inc' 'GOMSpace'
#  'Guardian Space Technology Solutions' 'HEAD Aerospace' 'HEO Robotics'
#  'HKATG' 'Hancom InSpace' 'HawkEye 360' 'Hawkeye 360' 'Hera Systems'
#  'Horizon Technologies' 'HySpecIQ LLC' 'Hydrosat' 'HyperSat LLC' 'Iceye'
#  'ImageSat' 'ImageSat International (ISI)' 'Inovor' 'JAXA'
#  'Jihua Laboratory' 'KARI' 'KP Labs' 'KSAT' 'Karten'
#  'Kazakhstan Gharysh Sapary' 'Kineis' 'Kleos Space SA' 'Koolock'
#  'Kuva Space' 'LatConnect' 'Live Earth Imaging' 'MDA'
#  'Maxar (DigitalGlobe)' 'MethaneSAT, LLC' 'MinoSpace' 'Myriota' 'NEC'
#  'Ningzia' 'NorthStar Earth & Space' 'OHB Italia' 'ORBCOMM'
#  'Orbital Effects (R2 Space)' 'Orbital Sidekick' 'Orora Tech' 'PIESat'
#  'Pixxel' 'Planet' 'Planet/JPL' 'PredaSAR' 'Qiansheng' 'Roscosmos'
#  'SATLANTIS' 'SCOUT' 'SI Imaging Services' 'SSTL' 'ST Electronics'
#  'ST Engineering' 'SatRevolution' 'Satellite Vu' 'Satellogic' 'Satrec'
#  'Scanway' 'Sen' 'Shaanxi Zhixing Space Technology'
#  'Shandong Institutes of Industrial Tech' 'Simera Group; ISISpace'
#  'Skeyeon' 'Space View Technology' 'SpaceBel' 'SpaceFab'
#  'SpaceView Technology' 'Spacety' 'Spire Global' 'Startical' 'Synspective'
#  'Technion' 'Teledyne Brown' 'Theia' 'Trident Space' 'UAE; Airbus' 'Umbra'
#  'Unseen Labs' 'Veoware Space' 'Virgin Orbit' 'Wyvern' 'XpressSAR'
#  'ZeroG Lab' 'Zhuhai' 'eGEOS' 'exactEarth (Spire Global)' 'iQPS']
# ['EO', 'HSI', 'RF', 'SAR', 'SSA']

# %%
import tkinter

window=tkinter.Tk()

window.title('GUI Program')

window.geometry('500x200')

 

#Creating a dropdown list of the companies

 

company_label=tkinter.Label(window, text='Company Selection:')

company_label.place(relx=.03, rely=.02)

 

company_options=c_array

 

company_inside=tkinter.StringVar(window)

company_inside.set('Select Company Name')

 

 

company_dropdown_list=tkinter.OptionMenu(window, company_inside, *company_options)

company_dropdown_list.place(relx=.03, rely=.05)

 

def print_company():

    print('Selected Option: {}'.format(company_inside.get()))

    return company_inside.get()

 

 

 

 

#Operational Status radio buttons

 

operation_label=tkinter.Label(window, text='Operational Status:')

operation_label.place(relx=0.15, rely=0.02)

operational_status=tkinter.StringVar()

 

operational_button=tkinter.Radiobutton(window, text='Operational', value='Operational', variable=operational_status)

operational_button.place(relx=.15, rely=.04)

non_operational_button=tkinter.Radiobutton(window, text='Non-Operational', value='Non-Operational', variable=operational_status)

non_operational_button.place(relx=.15, rely=.06)

decayed_button=tkinter.Radiobutton(window, text='Decayed', value='Decayed', variable=operational_status)

decayed_button.place(relx=.15, rely=.08)

 

operational_status.set('Operational')

 

def print_operation():

    print('Status Selected: {}'.format(operational_status.get()))

    return None

 

 

#Manual Entry Search by Satellite Name

name_label=tkinter.Label(window, text='Satellite Name:')

name_label.pack()

 

def print_name():

    print('Satellite Name is: ' + name_entry.get())

   

name_entry=tkinter.Entry(window)

name_entry.pack()

 

#Manual Entry Search by ID Number

ID_label=tkinter.Label(window, text='ID Number:')

ID_label.pack()

 

def print_ID():

    print('ID Number is: '+ID_entry.get())

   

ID_entry=tkinter.Entry(window)

ID_entry.pack()

 

#Check buttons in Python Satellite Constellation type

satellite_type_label=tkinter.Label(window, text='Satellite Type:')

satellite_type_label.place(relx=0.7, rely=0.02)


#Create buttons using for loop
#Proxy list to access tkinker.StringVar().get later on
count = 0
proxy = []
for var in s_array_f:
    satellite_type = tkinter.StringVar()
    proxy.append(satellite_type)
    button=tkinter.Checkbutton(window, text=var, variable=satellite_type, onvalue=var, offvalue='')
    button.place(relx=0.7, rely=0.04 + count * 0.02)
    count += 1


#Print out satellite types that are not None
def print_satellite_type():
    proxy_2 = []
    for x in proxy:
        if x.get():
            print('Type Selected: {}'.format(x.get()))
            proxy_2.append(x.get())
    return proxy_2
 



                             

#Submit Button

submit_button=tkinter.Button(window, text='Submit', command=lambda:[print_company(),print_operation(),print_name(), print_ID(), print_satellite_type()])

submit_button.place(relx=.03, rely=.35)

 

 

#Main loop

window.mainloop()

# %%
# def func():
#     if print_company() is not None and print_satellite_type() is None:
#         filtered = commercial["Company"] == str(print_company())
        
#     elif print_satellite_type() and print_company() is None:
#         filtered = commercial["Sensor Moda"] == " & ".join(print_satellite_type())
        
#     else:
#         filtered = (commercial["Company"] == str(print_company())) & (commercial["Sensor Moda"] == " & ".join(print_satellite_type()))
        
#     return filtered

# commercial[func()]
# Out:
# Selected Option: CNSA
# Selected Option: CNSA
# Empty DataFrame
# Columns: [Company, HQ Location, Constellation, Sensor Moda, Update, Pan, VNIR 400-1K nm, Unnamed: 7, Unnamed: 8, LWIR 8K-12K nm, Video, Multi-Sensor, 1st Satellite Launch, Full Constellation Revisit Rate, Spectral Range (nm) VNIR, # of Planned, Spatial Resolution (m), Band Width (nm), Spectral Range, # of HSI Bands, X-Band, C-Band, S-Band, L-Band, TBD-Band, Band, Band Width (nm) SWIR, Band Width (nm) MWIR, Band Width (nm) LWIR, Spectral Range (nm) VNIR.1, Unnamed: 30, Unnamed: 31, Unnamed: 32, Unnamed: 33, Unnamed: 34, Unnamed: 35, Unnamed: 36]
# Index: []
#
# [0 rows x 37 columns]

# %%
filtered = (commercial["Company"] == str(print_company()))
commercial[filtered]
# Out:
# Selected Option: CNSA
#     Company HQ Location   Constellation Sensor Moda Update          Pan  \
# 72     CNSA       China       GaoFen EO          EO    NaN  0.5m<=x<=1m
# 80     CNSA       China          ZiYuan          EO    NaN     1m<x<=5m
# 82     CNSA       China  GaoFen EO &HSI    EO & HSI      1    5m<x<=30m
# 126    CNSA       China      GaoFen SAR         SAR      1          NaN
# 137    CNSA       China      GeoFen HSI         HSI      1            0
#
#     VNIR 400-1K nm Unnamed: 7 Unnamed: 8 LWIR 8K-12K nm  ...  \
# 72        1m<x<=5m        NaN       >30m            NaN  ...
# 80       5m<x<=30m        NaN        NaN            NaN  ...
# 82       5m<x<=30m  5m<x<=30m       >30m           >30m  ...
# 126            NaN        NaN        NaN            NaN  ...
# 137              5         10          0              0  ...
#
#     Band Width (nm) MWIR  Band Width (nm) LWIR Spectral Range (nm) VNIR.1  \
# 72                   NaN                   NaN                        NaN
# 80                   NaN                   NaN                        NaN
# 82                   NaN                   NaN                        NaN
# 126                  NaN                   NaN                        NaN
# 137                  NaN                   NaN                        NaN
#
#     Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 72          NaN         NaN         NaN         NaN         NaN         NaN
# 80          NaN         NaN         NaN         NaN         NaN         NaN
# 82          NaN         NaN         NaN         NaN         NaN         NaN
# 126         NaN         NaN         NaN         NaN         NaN         NaN
# 137         NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 36
# 72          NaN
# 80          NaN
# 82          NaN
# 126         NaN
# 137         NaN
#
# [5 rows x 37 columns]

# %%
filtered = (commercial["Sensor Moda"] == " & ".join(print_satellite_type()))
commercial[filtered]
# Out:
# Type Selected: HSI
#                      Company          HQ Location  \
# 17                    Zhuhai                China
# 18                 Roscosmos               Russia
# 19          Orbital Sidekick                   US
# 20            Teledyne Brown                   US
# 21                  GOMSpace              Denmark
# 22                     Theia                   US
# 23                  SpaceFab                   US
# 24                    Pixxel             India/US
# 25              HySpecIQ LLC                   US
# 26              HyperSat LLC                   US
# 27          Orbital Sidekick                   US
# 28                Planet/JPL                   US
# 29                  SpaceBel              Belgium
# 30           MethaneSAT, LLC                   US
# 31     DragonFly; Space JLTZ  South Africa/Mexico
# 32                       CAS                China
# 33             SatRevolution               Poland
# 34                 Qiansheng                China
# 35      SpaceView Technology                China
# 36                    Wyvern               Canada
# 37              Virgin Orbit                   US
# 56   NorthStar Earth & Space               Canada
# 57                Kuva Space              Finland
# 58                 Bluefield                   US
# 59                GHGSat Inc               Canada
# 60                   KP Labs               Poland
# 137                     CNSA                China
# 138         Orbital Sidekick                   US
# 175              Chang Guang                China
#
#                          Constellation Sensor Moda      Update  Pan  \
# 17                          Zhuhai OHS         HSI         NaN  NaN
# 18                            Resurs-P         HSI         NaN  NaN
# 19                           ISS HEIST         HSI         NaN  NaN
# 20                               DESIS         HSI         NaN  NaN
# 21                                GOMX         HSI         NaN  NaN
# 22       THEIA Satellite Network (TSN)         HSI         NaN  NaN
# 23                           ViewPoint         HSI         NaN  NaN
# 24                      Pixxel (Anand)         HSI         NaN  NaN
# 25                            HySpecIQ         HSI         NaN  NaN
# 26                            HyperSat         HSI         NaN  NaN
# 27                               GHOSt         HSI         NaN  NaN
# 28                       Carbon Mapper         HSI         NaN  NaN
# 29                           ScanWorld         HSI         NaN  NaN
# 30                          MethaneSAT         HSI         NaN  NaN
# 31                         HyperActive         HSI         NaN  NaN
# 32                               SPARK         HSI         NaN  NaN
# 33                                 REC         HSI         NaN  NaN
# 34                           Qiansheng         HSI         NaN  NaN
# 35                       Superview HSI         HSI         NaN  NaN
# 36                           DragonEye         HSI         NaN  NaN
# 37          Virgin Orbit Constellation         HSI  Discovered  NaN
# 56                           Northstar         HSI         NaN  NaN
# 57                         Hello World         HSI         NaN  NaN
# 58   Methane Detection Microsatellites         HSI         NaN  NaN
# 59                              GHGSat         HSI         NaN  NaN
# 60                         Intuition-1         HSI         NaN  NaN
# 137                         GeoFen HSI         HSI           1    0
# 138                             Aurora         HSI           1    0
# 175                   Jilin-1 Spectrum         HSI         NaN  NaN
#
#     VNIR 400-1K nm Unnamed: 7 Unnamed: 8 LWIR 8K-12K nm  ...  \
# 17             NaN        NaN        NaN            NaN  ...
# 18             NaN        NaN        NaN            NaN  ...
# 19             NaN        NaN        NaN            NaN  ...
# 20             NaN        NaN        NaN            NaN  ...
# 21             NaN        NaN        NaN            NaN  ...
# 22             NaN        NaN        NaN            NaN  ...
# 23             NaN        NaN        NaN            NaN  ...
# 24             NaN        NaN        NaN            NaN  ...
# 25             NaN        NaN        NaN            NaN  ...
# 26             NaN        NaN        NaN            NaN  ...
# 27             NaN        NaN        NaN            NaN  ...
# 28             NaN        NaN        NaN            NaN  ...
# 29             NaN        NaN        NaN            NaN  ...
# 30             NaN        NaN        NaN            NaN  ...
# 31             NaN        NaN        NaN            NaN  ...
# 32             NaN        NaN        NaN            NaN  ...
# 33             NaN        NaN        NaN            NaN  ...
# 34             NaN        NaN        NaN            NaN  ...
# 35             NaN        NaN        NaN            NaN  ...
# 36             NaN        NaN        NaN            NaN  ...
# 37             NaN        NaN        NaN            NaN  ...
# 56             NaN        NaN        NaN            NaN  ...
# 57             NaN        NaN        NaN            NaN  ...
# 58             NaN        NaN        NaN            NaN  ...
# 59             NaN        NaN        NaN            NaN  ...
# 60             NaN        NaN        NaN            NaN  ...
# 137              5         10          0              0  ...
# 138              0          0          0              0  ...
# 175          4-115      30-80       1250           6000  ...
#
#     Band Width (nm) MWIR  Band Width (nm) LWIR Spectral Range (nm) VNIR.1  \
# 17                   NaN                   NaN                        NaN
# 18                   NaN                   NaN                        NaN
# 19                   NaN                   NaN                        NaN
# 20                   NaN                   NaN                        NaN
# 21                   NaN                   NaN                        NaN
# 22                   NaN                   NaN                        NaN
# 23                   NaN                   NaN                        NaN
# 24                   NaN                   NaN                        NaN
# 25                   NaN                   NaN                        NaN
# 26                   NaN                   NaN                        NaN
# 27                   NaN                   NaN                        NaN
# 28                   NaN                   NaN                        NaN
# 29                   NaN                   NaN                        NaN
# 30                   NaN                   NaN                        NaN
# 31                   NaN                   NaN                        NaN
# 32                   NaN                   NaN                        NaN
# 33                   NaN                   NaN                        NaN
# 34                   NaN                   NaN                        NaN
# 35                   NaN                   NaN                        NaN
# 36                   NaN                   NaN                        NaN
# 37                   NaN                   NaN                        NaN
# 56                   NaN                   NaN                        NaN
# 57                   NaN                   NaN                        NaN
# 58                   NaN                   NaN                        NaN
# 59                   NaN                   NaN                   400-1000
# 60                   NaN                   NaN                        NaN
# 137                  NaN                   NaN                        NaN
# 138                  NaN                   NaN                        NaN
# 175                  NaN                6000.0                   450-1040
#
#     Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 17          NaN         NaN         NaN         NaN         NaN         NaN
# 18          NaN         NaN         NaN         NaN         NaN         NaN
# 19          NaN         NaN         NaN         NaN         NaN         NaN
# 20          NaN         NaN         NaN         NaN         NaN         NaN
# 21          NaN         NaN         NaN         NaN         NaN         NaN
# 22          NaN         NaN         NaN         NaN         NaN         NaN
# 23          NaN         NaN         NaN         NaN         NaN         NaN
# 24          NaN         NaN         NaN         NaN         NaN         NaN
# 25          NaN         NaN         NaN         NaN         NaN         NaN
# 26          NaN         NaN         NaN         NaN         NaN         NaN
# 27          NaN         NaN         NaN         NaN         NaN         NaN
# 28          NaN         NaN         NaN         NaN         NaN         NaN
# 29          NaN         NaN         NaN         NaN         NaN         NaN
# 30          NaN         NaN         NaN         NaN         NaN         NaN
# 31          NaN         NaN         NaN         NaN         NaN         NaN
# 32          NaN         NaN         NaN         NaN         NaN         NaN
# 33          NaN         NaN         NaN         NaN         NaN         NaN
# 34          NaN         NaN         NaN         NaN         NaN         NaN
# 35          NaN         NaN         NaN         NaN         NaN         NaN
# 36          NaN         NaN         NaN         NaN         NaN         NaN
# 37          NaN         NaN         NaN         AIS         NaN         NaN
# 56          NaN         NaN         NaN         NaN         NaN         NaN
# 57          NaN         NaN         NaN         NaN         NaN         NaN
# 58    1600-1700         NaN         NaN         NaN         NaN         NaN
# 59          NaN         NaN         NaN         NaN         NaN         NaN
# 60          NaN         NaN         NaN         AIS         NaN         NaN
# 137         NaN         NaN         NaN         NaN         NaN         NaN
# 138         NaN         NaN         NaN          RF         NaN         NaN
# 175         NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 36
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 56          NaN
# 57          NaN
# 58          NaN
# 59          NaN
# 60          NaN
# 137         NaN
# 138         NaN
# 175         NaN
#
# [29 rows x 37 columns]

# %%
filtered = (commercial["Company"] == str(print_company())) & (commercial["Sensor Moda"] == " & ".join(print_satellite_type()))
commercial[filtered]
# Out:
# Selected Option: LatConnect
# Type Selected: EO
#       Company HQ Location Constellation Sensor Moda Update          Pan  \
# 0  LatConnect   Australia  LatConnect60          EO    NaN  0.5m<=x<=1m
#
#   VNIR 400-1K nm Unnamed: 7 Unnamed: 8 LWIR 8K-12K nm  ...  \
# 0       1m<x<=5m        NaN        NaN            NaN  ...
#
#   Band Width (nm) MWIR  Band Width (nm) LWIR Spectral Range (nm) VNIR.1  \
# 0                  NaN                   NaN                        NaN
#
#   Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 36
# 0         NaN
#
# [1 rows x 37 columns]

# %%
# Out:
#                      Company          HQ Location  \
# 17                    Zhuhai                China
# 18                 Roscosmos               Russia
# 19          Orbital Sidekick                   US
# 20            Teledyne Brown                   US
# 21                  GOMSpace              Denmark
# 22                     Theia                   US
# 23                  SpaceFab                   US
# 24                    Pixxel             India/US
# 25              HySpecIQ LLC                   US
# 26              HyperSat LLC                   US
# 27          Orbital Sidekick                   US
# 28                Planet/JPL                   US
# 29                  SpaceBel              Belgium
# 30           MethaneSAT, LLC                   US
# 31     DragonFly; Space JLTZ  South Africa/Mexico
# 32                       CAS                China
# 33             SatRevolution               Poland
# 34                 Qiansheng                China
# 35      SpaceView Technology                China
# 36                    Wyvern               Canada
# 37              Virgin Orbit                   US
# 56   NorthStar Earth & Space               Canada
# 57                Kuva Space              Finland
# 58                 Bluefield                   US
# 59                GHGSat Inc               Canada
# 60                   KP Labs               Poland
# 137                     CNSA                China
# 138         Orbital Sidekick                   US
# 175              Chang Guang                China
#
#                          Constellation Sensor Moda      Update  Pan  \
# 17                          Zhuhai OHS         HSI         NaN  NaN
# 18                            Resurs-P         HSI         NaN  NaN
# 19                           ISS HEIST         HSI         NaN  NaN
# 20                               DESIS         HSI         NaN  NaN
# 21                                GOMX         HSI         NaN  NaN
# 22       THEIA Satellite Network (TSN)         HSI         NaN  NaN
# 23                           ViewPoint         HSI         NaN  NaN
# 24                      Pixxel (Anand)         HSI         NaN  NaN
# 25                            HySpecIQ         HSI         NaN  NaN
# 26                            HyperSat         HSI         NaN  NaN
# 27                               GHOSt         HSI         NaN  NaN
# 28                       Carbon Mapper         HSI         NaN  NaN
# 29                           ScanWorld         HSI         NaN  NaN
# 30                          MethaneSAT         HSI         NaN  NaN
# 31                         HyperActive         HSI         NaN  NaN
# 32                               SPARK         HSI         NaN  NaN
# 33                                 REC         HSI         NaN  NaN
# 34                           Qiansheng         HSI         NaN  NaN
# 35                       Superview HSI         HSI         NaN  NaN
# 36                           DragonEye         HSI         NaN  NaN
# 37          Virgin Orbit Constellation         HSI  Discovered  NaN
# 56                           Northstar         HSI         NaN  NaN
# 57                         Hello World         HSI         NaN  NaN
# 58   Methane Detection Microsatellites         HSI         NaN  NaN
# 59                              GHGSat         HSI         NaN  NaN
# 60                         Intuition-1         HSI         NaN  NaN
# 137                         GeoFen HSI         HSI           1    0
# 138                             Aurora         HSI           1    0
# 175                   Jilin-1 Spectrum         HSI         NaN  NaN
#
#     VNIR 400-1K nm Unnamed: 7 Unnamed: 8 LWIR 8K-12K nm  ...  \
# 17             NaN        NaN        NaN            NaN  ...
# 18             NaN        NaN        NaN            NaN  ...
# 19             NaN        NaN        NaN            NaN  ...
# 20             NaN        NaN        NaN            NaN  ...
# 21             NaN        NaN        NaN            NaN  ...
# 22             NaN        NaN        NaN            NaN  ...
# 23             NaN        NaN        NaN            NaN  ...
# 24             NaN        NaN        NaN            NaN  ...
# 25             NaN        NaN        NaN            NaN  ...
# 26             NaN        NaN        NaN            NaN  ...
# 27             NaN        NaN        NaN            NaN  ...
# 28             NaN        NaN        NaN            NaN  ...
# 29             NaN        NaN        NaN            NaN  ...
# 30             NaN        NaN        NaN            NaN  ...
# 31             NaN        NaN        NaN            NaN  ...
# 32             NaN        NaN        NaN            NaN  ...
# 33             NaN        NaN        NaN            NaN  ...
# 34             NaN        NaN        NaN            NaN  ...
# 35             NaN        NaN        NaN            NaN  ...
# 36             NaN        NaN        NaN            NaN  ...
# 37             NaN        NaN        NaN            NaN  ...
# 56             NaN        NaN        NaN            NaN  ...
# 57             NaN        NaN        NaN            NaN  ...
# 58             NaN        NaN        NaN            NaN  ...
# 59             NaN        NaN        NaN            NaN  ...
# 60             NaN        NaN        NaN            NaN  ...
# 137              5         10          0              0  ...
# 138              0          0          0              0  ...
# 175          4-115      30-80       1250           6000  ...
#
#     Band Width (nm) MWIR  Band Width (nm) LWIR Spectral Range (nm) VNIR.1  \
# 17                   NaN                   NaN                        NaN
# 18                   NaN                   NaN                        NaN
# 19                   NaN                   NaN                        NaN
# 20                   NaN                   NaN                        NaN
# 21                   NaN                   NaN                        NaN
# 22                   NaN                   NaN                        NaN
# 23                   NaN                   NaN                        NaN
# 24                   NaN                   NaN                        NaN
# 25                   NaN                   NaN                        NaN
# 26                   NaN                   NaN                        NaN
# 27                   NaN                   NaN                        NaN
# 28                   NaN                   NaN                        NaN
# 29                   NaN                   NaN                        NaN
# 30                   NaN                   NaN                        NaN
# 31                   NaN                   NaN                        NaN
# 32                   NaN                   NaN                        NaN
# 33                   NaN                   NaN                        NaN
# 34                   NaN                   NaN                        NaN
# 35                   NaN                   NaN                        NaN
# 36                   NaN                   NaN                        NaN
# 37                   NaN                   NaN                        NaN
# 56                   NaN                   NaN                        NaN
# 57                   NaN                   NaN                        NaN
# 58                   NaN                   NaN                        NaN
# 59                   NaN                   NaN                   400-1000
# 60                   NaN                   NaN                        NaN
# 137                  NaN                   NaN                        NaN
# 138                  NaN                   NaN                        NaN
# 175                  NaN                6000.0                   450-1040
#
#     Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 17          NaN         NaN         NaN         NaN         NaN         NaN
# 18          NaN         NaN         NaN         NaN         NaN         NaN
# 19          NaN         NaN         NaN         NaN         NaN         NaN
# 20          NaN         NaN         NaN         NaN         NaN         NaN
# 21          NaN         NaN         NaN         NaN         NaN         NaN
# 22          NaN         NaN         NaN         NaN         NaN         NaN
# 23          NaN         NaN         NaN         NaN         NaN         NaN
# 24          NaN         NaN         NaN         NaN         NaN         NaN
# 25          NaN         NaN         NaN         NaN         NaN         NaN
# 26          NaN         NaN         NaN         NaN         NaN         NaN
# 27          NaN         NaN         NaN         NaN         NaN         NaN
# 28          NaN         NaN         NaN         NaN         NaN         NaN
# 29          NaN         NaN         NaN         NaN         NaN         NaN
# 30          NaN         NaN         NaN         NaN         NaN         NaN
# 31          NaN         NaN         NaN         NaN         NaN         NaN
# 32          NaN         NaN         NaN         NaN         NaN         NaN
# 33          NaN         NaN         NaN         NaN         NaN         NaN
# 34          NaN         NaN         NaN         NaN         NaN         NaN
# 35          NaN         NaN         NaN         NaN         NaN         NaN
# 36          NaN         NaN         NaN         NaN         NaN         NaN
# 37          NaN         NaN         NaN         AIS         NaN         NaN
# 56          NaN         NaN         NaN         NaN         NaN         NaN
# 57          NaN         NaN         NaN         NaN         NaN         NaN
# 58    1600-1700         NaN         NaN         NaN         NaN         NaN
# 59          NaN         NaN         NaN         NaN         NaN         NaN
# 60          NaN         NaN         NaN         AIS         NaN         NaN
# 137         NaN         NaN         NaN         NaN         NaN         NaN
# 138         NaN         NaN         NaN          RF         NaN         NaN
# 175         NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 36
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 56          NaN
# 57          NaN
# 58          NaN
# 59          NaN
# 60          NaN
# 137         NaN
# 138         NaN
# 175         NaN
#
# [29 rows x 37 columns]
