# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import graph_module as gm

# %%
commercial = pd.read_csv('Commercial2.csv')
commercial.head()
# Out:
#       Company HQ Location                  Constellation Sat Name  ID  \
# 0  LatConnect   Australia                   LatConnect60      NaN NaN
# 1   SATLANTIS    US/Spain                      SATLANTIS      NaN NaN
# 2      Zhuhai       China            Zhuhai-1 (OIS, OVS)      NaN NaN
# 3       Canon       Japan                         CE-SAT      NaN NaN
# 4       Theia          US  THEIA Satellite Network (TSN)      NaN NaN
#
#   Sensor Moda Update          Pan VNIR 400-1K nm Unnamed: 9  ...  \
# 0          EO    NaN  0.5m<=x<=1m       1m<x<=5m        NaN  ...
# 1          EO    NaN  0.5m<=x<=1m    0.5m<=x<=1m        NaN  ...
# 2          EO    NaN  0.5m<=x<=1m            NaN        NaN  ...
# 3          EO    NaN          NaN    0.5m<=x<=1m        NaN  ...
# 4          EO    NaN          NaN    0.5m<=x<=1m        NaN  ...
#
#   Spectral Range (nm) VNIR.1 Unnamed: 32 Unnamed: 33  Unnamed: 34 Unnamed: 35  \
# ...

# %%
data = (commercial["Sensor Moda"] == "EO") & (commercial["Company"] == "LatConnect")
commercial[data]
gm.createGraph("HawkEye 360.csv")

# %%
#Create list of Companies
c_array = np.unique(commercial["Company"].to_numpy()) 
h_array = np.unique(commercial["HQ Location"].to_numpy())
commercial['ID'] = commercial['ID'].astype('Int64')


#Create unique list of Sensor Moda without &

def myFunc(string):
    if "&" in string:
        return False
    else:
        return True
s_array = np.unique(commercial["Sensor Moda"].to_numpy())
s_array_f = list(filter(myFunc, s_array))
s_array_f
# Out:
# ['EO', 'HSI', 'RF', 'SAR', 'SSA']

# %%
import tkinter

window=tkinter.Tk()

window.title('GUI Program')

window.geometry('500x200')

 

#Creating a dropdown list of the companies

 

company_label=tkinter.Label(window, text='Company Name:')

company_label.place(relx=.03, rely=.02)

 
#Currently just 4 companies
company_options = ["Hawkeye 360", "Planet", "Capella Space", "Iceye"]
#company_options=[c_array]

 

company_inside=tkinter.StringVar(window)

company_inside.set('Select Company Name')

 

 

company_dropdown_list=tkinter.OptionMenu(window, company_inside, *company_options)

company_dropdown_list.place(relx=.03, rely=.05)


def return_Company():

    return str(company_inside.get()) 


def print_Company():

    print('Company Selected: {}'.format(company_inside.get()))

    return str(company_inside.get())

 

 

 

 

#Operational Status radio buttons

 

hq_label=tkinter.Label(window, text='HQ Location:')

hq_label.place(relx=.15, rely=.02)

 

hq_options=h_array

 

hq_inside=tkinter.StringVar(window)

hq_inside.set('Select HQ Location')

 

 

hq_dropdown_list=tkinter.OptionMenu(window, hq_inside, *hq_options)
hq_dropdown_list.place(relx=.15, rely=.05)

 

def return_hq():
    return str(hq_inside.get())
 

def print_hq():

    print('Location Selected: {}'.format(hq_inside.get()))

    


 

 

#Manual Entry Search by Satellite Name

name_label=tkinter.Label(window, text='Satellite Name:')

name_label.pack()

 

def print_name():

    print('Satellite Name is: ' + name_entry.get())

   

name_entry=tkinter.Entry(window)

name_entry.pack()

 

#Manual Entry Search by ID Number

ID_label=tkinter.Label(window, text='ID Number:')

ID_label.pack()

 

def print_ID():

    print('ID Number is: '+ID_entry.get())

   

ID_entry=tkinter.Entry(window)

ID_entry.pack()

 

#Check buttons in Python Satellite Constellation type

satellite_type_label=tkinter.Label(window, text='Satellite Type:')

satellite_type_label.place(relx=0.7, rely=0.02)


#Create buttons using for loop
#Proxy list to access tkinker.StringVar().get later on
count = 0
proxy = []
for var in s_array_f:
    satellite_type = tkinter.StringVar()
    proxy.append(satellite_type)
    button=tkinter.Checkbutton(window, text=var, variable=satellite_type, onvalue=var, offvalue='')
    button.place(relx=0.7, rely=0.04 + count * 0.02)
    count += 1


#Print out satellite types that are not None
def print_Sensor_Moda():
    proxy_2 = []
    for x in proxy:
        if x.get():
            print('Type Selected: {}'.format(x.get()))
            proxy_2.append(x.get())
    return " & ".join(proxy_2)

def return_Sensor_Moda():
    proxy_2 = []
    for x in proxy:
        if x.get():
            proxy_2.append(x.get())
    return " & ".join(proxy_2)
 


                             

#Submit Button

submit_button=tkinter.Button(window, text='Submit', command=lambda:[print_Company(),print_hq(),print_name(), print_ID(), print_Sensor_Moda()])

submit_button.place(relx=.03, rely=.35)




#Main loop

window.mainloop()


def filterData():
    col = ["Company", "HQ Location", "Sensor Moda"]
    fields = dict.fromkeys(col,0)
    fields_1 = {"Company": "return_Company()" , "HQ Location": "return_hq()", "Sensor Moda": "return_Sensor_Moda()"}
    def update (fields):
        if (len(return_Sensor_Moda()) != 0):
            fields["Sensor Moda"] = 1
        if return_Company() != "Select Company Name":
            fields["Company"] = 1
        if return_hq() != "Select HQ Location":
            fields["HQ Location"] = 1
    update(fields)


    initial_filter = True
    for key in fields.keys():
        if fields.get(key) == 1:
            filtered = initial_filter & (commercial[key] == eval(fields_1.get(key)))
            initial_filter = filtered
#     IdSatName = commercial[initial_filter][["ID","Sat Name"]]
    return commercial[initial_filter]



#New Window for Output
import tkinter as tk
from tkinter import *
ws = Tk()
ws.title('NORAD ID and Sat Name of Queried Satellites')
ws.geometry('400x300')
ws.config(bg='#84BF04')



text_box = Text(
    ws,
    height=25,
    width=60
)
text_box.pack(expand=True)
text_box.insert('end', filterData()[["ID","Sat Name"]])
text_box.config(state='disabled')



ws.mainloop()




from glob import glob
import os
 
root = tk.Tk()
lb = tk.Listbox(root)
lb.pack()
y=filterData()["Company"].tolist()

if 'Capella Space' in y:
    fl = glob(r"C:\Users\S33088\Downloads\CapellaVid.mp4")
    
elif 'Hawkeye 360' in y:
    fl = glob(r"C:\Users\S33088\Downloads\HawkeyeVid.mp4")
elif 'Iceye' in y:
    fl = glob(r"C:\Users\S33088\Downloads\IceyeVid.mp4")
elif "Planet" in y:
    fl = glob(r"C:\Users\S33088\Downloads\PlanetVid.mp4")
    
#"C:\Users\S33088\OneDrive - Noblis\Documents\STK 12\STK_Movies_VDFs\First Movie.mp4"
for f in fl:
    lb.insert(0,f)
 
def fname():
    return lb.get(lb.curselection())
 
def play():
    os.startfile(fname())
 
lb.bind("<Double-Button>", lambda x: play())
 
la = tk.Label(root, text = "Select a file")
la.pack()
 
def see_properties():
    size = os.path.getsize(fname()) // 1000000
    la['text'] = size
 
lb.bind("<<ListboxSelect>>", lambda x: see_properties())
 
root.mainloop()

        
 
# print(commercial[initial_filter].iloc[:,:5])
# print(commercial[initial_filter][["ID","Sat Name"]])

win = tk.Tk()
def graph():
    #Setting up Analytical Data


    import matplotlib.pyplot as plt

    from matplotlib import colors

    from matplotlib.ticker import PercentFormatter

    import matplotlib
    import pandas as pd





    # # function to add value labels

    # def addlabels(x,y):

    #     for i in range(len(x)):

    #         plt.text(i, y[i], y[i], ha = 'center')

    #OR

    # for i, v in enumerate(y):

    #     ax.text(v + 3, i + .25, str(v), color='blue', fontweight='bold')



    #Reading excel data

    excel_sensor_data_sheet= 'analytics_sheet_sensortypes.xlsx'



    #Capella Sheet

    df_capella_sheet=pd.read_excel(excel_sensor_data_sheet, sheet_name='Capella')

    capella_types=df_capella_sheet["Sensor Type"].tolist()

    capella_counts=df_capella_sheet["Satellite Count"].tolist()

    capella_final_dfsheet=pd.DataFrame({'Sensor Type':capella_types, 'Satellite Count':capella_counts})



    #Hawkeye 360 Sheet

    df_hawkeye_sheet=pd.read_excel(excel_sensor_data_sheet, sheet_name='Hawkeye 360')

    hawkeye_types=df_hawkeye_sheet['Sensor Type'].tolist()

    hawkeye_counts=df_hawkeye_sheet['Satellite Count'].tolist()

    hawkeye_final_dfsheet=pd.DataFrame({'Sensor Type':hawkeye_types, 'Satellite Count':hawkeye_counts})



    #Iceye Sheet

    df_iceye_sheet=pd.read_excel(excel_sensor_data_sheet, sheet_name='Iceye')

    iceye_types=df_iceye_sheet['Sensor Type'].tolist()

    iceye_counts=df_iceye_sheet['Satellite Count'].tolist()

    iceye_final_dfsheet=pd.DataFrame({'Sensor Type':iceye_types, 'Satellite Count':iceye_counts})



    #Planet Sheet

    df_planet_sheet=pd.read_excel(excel_sensor_data_sheet, sheet_name='Planet')

    planet_types=df_planet_sheet['Sensor Type'].tolist()

    planet_counts=df_planet_sheet['Satellite Count'].tolist()

    planet_final_dfsheet=pd.DataFrame({'Sensor Type': planet_types, 'Satellite Count':planet_counts})





    excel_launch_data_sheet= 'analytics_sheet_launchdates.xlsx'



    #Capella launch info

    capella=pd.read_excel(excel_launch_data_sheet, sheet_name='Capella')

    capella_years=capella["Launch Year"].tolist()

    capella_num=capella["# of Satellites launched"].tolist()

    capella_final=pd.DataFrame({'Launch Year':capella_years, '# of Satellites launched':capella_num})



    #Hawkeye Launch info

    hawkeye=pd.read_excel(excel_launch_data_sheet, sheet_name='Hawkeye 360')

    hawkeye_years=hawkeye["Launch Year"].tolist()

    hawkeye_num=hawkeye["# of Satellites launched"].tolist()

    hawkeye_final=pd.DataFrame({'Launch Year':hawkeye_years, '# of Satellites launched':hawkeye_num})



    #Iceye Launch info

    iceye=pd.read_excel(excel_launch_data_sheet, sheet_name='Iceye')

    iceye_years=iceye["Launch Year"].tolist()

    iceye_num=iceye["# of Satellites launched"].tolist()

    iceye_final=pd.DataFrame({'Launch Year':iceye_years, '# of Satellites launched':iceye_num})



    #Planet Launch info

    planet=pd.read_excel(excel_launch_data_sheet, sheet_name='Planet')

    planet_years=planet["Launch Year"].tolist()

    planet_num=planet["# of Satellites launched"].tolist()

    planet_final=pd.DataFrame({'Launch Year':planet_years, '# of Satellites launched':planet_num})



    #Displaying Anaylytical Data

    y=filterData()["Company"].tolist()

    if 'Capella Space' in y:

        a1=capella_final_dfsheet.plot.bar(x='Sensor Type', y='Satellite Count', label='Capella Satellites')

        plt.ylabel('# of Satellites')

        plt.title('Sensor Modalities of all Capella Space Satellites')

        a2=capella_final.plot.bar(x='Launch Year', y='# of Satellites launched', color='red', label='Capella Satellites')

        plt.ylabel('# of Satellites Launched')

        plt.title('Number of Capella Space Satellites Launched per Year')

    elif 'Hawkeye 360' in y:

        b1=hawkeye_final_dfsheet.plot.bar(x='Sensor Type', y='Satellite Count', label='Hawkeye 360 Satellites')

        plt.ylabel('# of Satellites')

        plt.title('Sensor Modalities of all Hawkeye 360 Space Satellites')

        a2=hawkeye_final.plot.bar(x='Launch Year', y='# of Satellites launched', color='red', label='Hawkeye 360 Satellites')

        plt.ylabel('# of Satellites Launched')

        plt.title('Number of Hawkeye 360 Satellites Launched per Year')

    elif 'Iceye' in y:

        c1=iceye_final_dfsheet.plot.bar(x='Sensor Type', y='Satellite Count', label='Iceye Satellites')

        plt.ylabel('# of Satellites')

        plt.title('Sensor Modalities of all Iceye Space Satellites')

        a2=iceye_final.plot.bar(x='Launch Year', y='# of Satellites launched', color='red', label='Iceye Satellites')

        plt.ylabel('# of Satellites Launched')

        plt.title('Number of Iceye Satellites Launched per Year')

    elif 'Planet' in y:

        d1=planet_final_dfsheet.plot.bar(x='Sensor Type', y='Satellite Count', label='Planet Satellites')

        plt.ylabel('# of Satellites')

        plt.title('Sensor Modalities of all Planet Space Satellites')

        a2=planet_final.plot.bar(x='Launch Year', y='# of Satellites launched', color='red', label='Planet Satellites')

        plt.ylabel('# of Satellites Launched')

        plt.title('Number of Planet Satellites Launched per Year')

    plt.show()
def graphCapella():
    gm.createGraph('Capella Space.csv')
def graphHawk():
    gm.createGraph('HawkEye 360.csv')
def graphIce():
    gm.createGraph('Iceye.csv')
def graphPlanet():
    gm.createGraph('Planet Labs.csv')

label = tk.Label(win,text="Space Action Budget for each Company by Year and Contracting Agency", 
                 font=("Helvetica",14)).place(x = 0, y = 0)


label = tk.Label(win,text="Number of Satellites and Sensor Modalities of Selected Company", 
                 font=("Helvetica",14)).place(x = 0, y = 400)

tk.Button(win, text='Capella', command=graphCapella).grid(row=0, column=0,padx=0, pady=100) # Call the graph_1 function
tk.Button(win, text='Hawkeye 360', command=graphHawk).grid(row=0, column=1,padx=0, pady=100)
tk.Button(win, text='Iceye', command=graphIce).grid(row=0, column=2,padx=0, pady=100)
tk.Button(win, text='Planet Labs', command=graphPlanet).grid(row=0, column=3,padx=0, pady=100)
btn = tk.Button(win, text='Display', command=graph)
btn.place(x=0, y=500)

win.mainloop()
# Out:
# Company Selected: Hawkeye 360
# Location Selected: Select HQ Location
# Satellite Name is:
# ID Number is:

# %%
#Code that filters data

#Create dictionary that lists which fields are selected
col = ["Company", "HQ Location", "Sensor Moda"]
fields = dict.fromkeys(col,0)
fields_1 = {"Company": "return_Company()" , "HQ Location": "return_hq()", "Sensor Moda": "return_Sensor_Moda()"}
def update (fields):
    if (len(return_Sensor_Moda()) != 0):
        fields["Sensor Moda"] = 1
    if return_Company() != "Select Company Name":
        fields["Company"] = 1
    if return_hq() != "Select HQ Location":
        fields["HQ Location"] = 1
update(fields)


initial_filter = True
for key in fields.keys():
    if fields.get(key) == 1:
        filtered = initial_filter & (commercial[key] == eval(fields_1.get(key)))
        initial_filter = filtered


# print(commercial[initial_filter].iloc[:,:6])
# print(commercial[initial_filter][["ID","Sat Name"]])
